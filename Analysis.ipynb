# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import matplotlib.pyplot as plt
from datetime import datetime

# %%
pd.set_option('display.max_columns', None)
movies = pd.read_csv("movies2.csv")
tags = pd.read_csv("tags2.csv")
ratings = pd.read_csv("ratings2.csv")
links = pd.read_csv("links2.csv")

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
movies = movies.drop_duplicates(subset="title")

# %%
movies[movies["genres"] == "(no genres listed)"]
# Out:
#       movieId                                              title  \
# 8517   114335                                  La cravate (1957)
# 8684   122888                                     Ben-hur (2016)
# 8687   122896  Pirates of the Caribbean: Dead Men Tell No Tal...
# 8782   129250                                  Superfast! (2015)
# 8836   132084                                Let It Be Me (1995)
# 8902   134861               Trevor Noah: African American (2013)
# 9033   141131                                   Guardians (2016)
# 9053   141866                                  Green Room (2015)
# 9070   142456                     The Brand New Testament (2015)
# 9091   143410                                         Hyena Road
# 9138   147250  The Adventures of Sherlock Holmes and Doctor W...
# 9178   149330                          A Cosmic Christmas (1977)
# 9217   152037                                 Grease Live (2016)
# 9248   155589                             Noin 7 veljestä (1968)
# 9259   156605                                           Paterson
# 9307   159161                        Ali Wong: Baby Cobra (2016)
# 9316   159779                   A Midsummer Night's Dream (2016)
# 9348   161008                         The Forbidden Dance (1990)
# 9413   165489                              Ethel & Ernest (2016)
# 9426   166024                                    Whiplash (2013)
# 9448   167570                                             The OA
# 9478   169034                                    Lemonade (2016)
# 9514   171495                                             Cosmos
# 9515   171631                            Maria Bamford: Old Baby
# 9518   171749                  Death Note: Desu nôto (2006–2007)
# 9525   171891                                  Generation Iron 2
# 9534   172497                  T2 3-D: Battle Across Time (1996)
# 9541   172591            The Godfather Trilogy: 1972-1990 (1992)
# 9562   173535  The Adventures of Sherlock Holmes and Doctor W...
# 9573   174403                        The Putin Interviews (2017)
# 9611   176601                                       Black Mirror
# 9661   181413  Too Funny to Fail: The Life and Death of The D...
# 9663   181719  Serving in Silence: The Margarethe Cammermeyer...
# 9669   182727                     A Christmas Story Live! (2017)
#
#                   genres
# 8517  (no genres listed)
# 8684  (no genres listed)
# 8687  (no genres listed)
# 8782  (no genres listed)
# 8836  (no genres listed)
# 8902  (no genres listed)
# 9033  (no genres listed)
# 9053  (no genres listed)
# 9070  (no genres listed)
# 9091  (no genres listed)
# 9138  (no genres listed)
# 9178  (no genres listed)
# 9217  (no genres listed)
# 9248  (no genres listed)
# 9259  (no genres listed)
# 9307  (no genres listed)
# 9316  (no genres listed)
# 9348  (no genres listed)
# 9413  (no genres listed)
# 9426  (no genres listed)
# 9448  (no genres listed)
# 9478  (no genres listed)
# 9514  (no genres listed)
# 9515  (no genres listed)
# 9518  (no genres listed)
# 9525  (no genres listed)
# 9534  (no genres listed)
# 9541  (no genres listed)
# 9562  (no genres listed)
# 9573  (no genres listed)
# 9611  (no genres listed)
# 9661  (no genres listed)
# 9663  (no genres listed)
# 9669  (no genres listed)

# %%
movies["genres"].value_counts()
# Out:
# Drama                                       1053
# Comedy                                       946
# Comedy|Drama                                 435
# Comedy|Romance                               363
# Drama|Romance                                348
#                                             ...
# Action|Crime|Drama|War                         1
# Action|Children|Sci-Fi|IMAX                    1
# Action|Adventure|Comedy|Fantasy|Horror         1
# Adventure|Children|Comedy|Romance|Sci-Fi       1
# Comedy|War|Western                             1
# Name: genres, Length: 951, dtype: int64

# %%
movies.describe()
# Out:
#              movieId
# count    9737.000000
# mean    42165.340865
# std     52136.321521
# min         1.000000
# 25%      3247.000000
# 50%      7294.000000
# 75%     76173.000000
# max    193609.000000

# %%
def convert_timestamp(data):
    date = []
    for timestamp in data["timestamp"]:
        to_date = datetime.fromtimestamp(timestamp).strftime('%d-%m-%y')
        date.append(to_date)
    data["date"] = date
    del data["timestamp"]
    return data

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
ratings = convert_timestamp(ratings)
ratings
# Out:
#         userId  movieId  rating      date
# 0            1        1     4.0  30-07-00
# 1            1        3     4.0  30-07-00
# 2            1        6     4.0  30-07-00
# 3            1       47     5.0  30-07-00
# 4            1       50     5.0  30-07-00
# ...        ...      ...     ...       ...
# 100831     610   166534     4.0  04-05-17
# 100832     610   168248     5.0  04-05-17
# 100833     610   168250     5.0  08-05-17
# 100834     610   168252     5.0  04-05-17
# 100835     610   170875     3.0  04-05-17
#
# [100836 rows x 4 columns]

# %%
ratings.describe()
# Out:
#               userId        movieId         rating
# count  100836.000000  100836.000000  100836.000000
# mean      326.127564   19435.295718       3.501557
# std       182.618491   35530.987199       1.042529
# min         1.000000       1.000000       0.500000
# 25%       177.000000    1199.000000       3.000000
# 50%       325.000000    2991.000000       3.500000
# 75%       477.000000    8122.000000       4.000000
# max       610.000000  193609.000000       5.000000

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
links.describe()
# Out:
#              movieId        imdbId         tmdbId
# count    9742.000000  9.742000e+03    9734.000000
# mean    42200.353623  6.771839e+05   55162.123793
# std     52160.494854  1.107228e+06   93653.481487
# min         1.000000  4.170000e+02       2.000000
# 25%      3248.250000  9.518075e+04    9665.500000
# 50%      7300.000000  1.672605e+05   16529.000000
# 75%     76232.000000  8.055685e+05   44205.750000
# max    193609.000000  8.391976e+06  525662.000000

# %%
data = ratings.merge(movies,on='movieId')
data = data.merge(links,on='movieId')
data = data.drop(columns = 'tmdbId')
data["imdbId"] = "www.imdb.com/title/tt" + data["imdbId"].astype(str)
data.rename(columns = {'imdbId':'link'}, inplace = True)
data['published year'] = data.title.str.extract('(\(\d\d\d\d\))',expand=False)

# %%
data
# Out:
#         userId  movieId  rating      date                             title  \
# 0            1        1     4.0  30-07-00                  Toy Story (1995)
# 1            5        1     4.0  08-11-96                  Toy Story (1995)
# 2            7        1     4.5  25-01-05                  Toy Story (1995)
# 3           15        1     2.5  13-11-17                  Toy Story (1995)
# 4           17        1     4.5  18-05-11                  Toy Story (1995)
# ...        ...      ...     ...       ...                               ...
# 100825     610   160341     2.5  19-11-16                  Bloodmoon (1997)
# 100826     610   160527     4.5  19-11-16  Sympathy for the Underdog (1971)
# 100827     610   160836     3.0  03-05-17                     Hazard (2005)
# 100828     610   163937     3.5  04-05-17                Blair Witch (2016)
# 100829     610   163981     3.5  04-05-17                         31 (2016)
#
#                                              genres  \
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1       Adventure|Animation|Children|Comedy|Fantasy
# 2       Adventure|Animation|Children|Comedy|Fantasy
# 3       Adventure|Animation|Children|Comedy|Fantasy
# 4       Adventure|Animation|Children|Comedy|Fantasy
# ...                                             ...
# 100825                              Action|Thriller
# 100826                           Action|Crime|Drama
# 100827                        Action|Drama|Thriller
# 100828                              Horror|Thriller
# 100829                                       Horror
#
#                                 link published year
# 0        www.imdb.com/title/tt114709         (1995)
# 1        www.imdb.com/title/tt114709         (1995)
# 2        www.imdb.com/title/tt114709         (1995)
# 3        www.imdb.com/title/tt114709         (1995)
# 4        www.imdb.com/title/tt114709         (1995)
# ...                              ...            ...
# 100825   www.imdb.com/title/tt118745         (1997)
# 100826    www.imdb.com/title/tt66806         (1971)
# 100827   www.imdb.com/title/tt798722         (2005)
# 100828  www.imdb.com/title/tt1540011         (2016)
# 100829  www.imdb.com/title/tt3835080         (2016)
#
# [100830 rows x 8 columns]

# %% [markdown]
# ### No row dublicated in the data

# %%
data.duplicated(["movieId","userId", "rating", "date"]).sum()
# Out:
# 0

# %%
plt.figure(figsize = (12, 8))
ax = sns.countplot(x="rating", data = data)
plt.title("Count Ratings in train data", fontsize = 20)
plt.xlabel("Ratings", fontsize = 20)
plt.ylabel("Number of Ratings", fontsize = 20)
plt.show()

# %% [markdown]
# ### Find the number of rated movies per user

# %%
num_rated_movies_per_user = data.groupby(by = "userId")["rating"].count().sort_values(ascending = False)
num_rated_movies_per_user.head()
# Out:
# userId
# 414    2698
# 599    2478
# 474    2108
# 448    1864
# 274    1346
# Name: rating, dtype: int64

# %% [markdown]
# ### Find the rating number per Movie

# %%
num_ratings_per_movie = data.groupby(by = "title")["rating"].count().sort_values(ascending = False)
num_ratings_per_movie.head()
# Out:
# title
# Forrest Gump (1994)                 329
# Shawshank Redemption, The (1994)    317
# Pulp Fiction (1994)                 307
# Silence of the Lambs, The (1991)    279
# Matrix, The (1999)                  278
# Name: rating, dtype: int64

# %%
data.describe()
# Out:
#               userId        movieId         rating
# count  100830.000000  100830.000000  100830.000000
# mean      326.131618   19430.333839       3.501567
# std       182.616577   35523.902852       1.042548
# min         1.000000       1.000000       0.500000
# 25%       177.000000    1199.000000       3.000000
# 50%       325.000000    2991.000000       3.500000
# 75%       477.000000    8118.750000       4.000000
# max       610.000000  193609.000000       5.000000

# %%
avg_rating = data.groupby('title').rating.sum()/data.groupby('title').rating.count()
avg_rating.sort_values(ascending = False)
# Out:
# title
# Karlson Returns (1970)                           5.0
# Winter in Prostokvashino (1984)                  5.0
# My Love (2006)                                   5.0
# Sorority House Massacre II (1990)                5.0
# Winnie the Pooh and the Day of Concern (1972)    5.0
#                                                 ...
# The Beast of Hollow Mountain (1956)              0.5
# Follow Me, Boys! (1966)                          0.5
# The Butterfly Effect 3: Revelations (2009)       0.5
# The Emoji Movie (2017)                           0.5
# Rust and Bone (De rouille et d'os) (2012)        0.5
# Name: rating, Length: 9719, dtype: float64

# %%
corrMatt = data.corr()
mask = np.array(corrMatt)
mask[np.tril_indices_from(mask)] = False
fig,ax= plt.subplots()
fig.set_size_inches(20,10)
sns.heatmap(corrMatt, mask=mask,vmax=.8, square=True,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div style = "color: blue"> <h3> no outlires in the data to remove </h3></div>

# %%
def get_feature_types_stats(df):
    # Find datatype for each feature in the data and return it with features name
    features = df.dtypes.rename('feature_type').reset_index().rename(columns={'index':'feature'})
    return features

def get_feature_stats(df):
    # Find missing percentage and missing count in the original data for each featue and return it
    missing_stats = df.isna().sum().rename('missing_count').reset_index().rename(columns={'index':'feature'})
    missing_stats['missing_percentage'] = missing_stats['missing_count']/df.shape[0]
    
    feature_types_df = get_feature_types_stats(df)
    
    missing_stats = missing_stats.merge(feature_types_df,
                         left_on='feature',
                         right_on='feature',
                         how='left')
    return missing_stats

# %%
missing_data = get_feature_stats(data)

# %%
missing_data
# Out:
#           feature  missing_count  missing_percentage feature_type
# 0          userId              0            0.000000        int64
# 1         movieId              0            0.000000        int64
# 2          rating              0            0.000000      float64
# 3            date              0            0.000000       object
# 4           title              0            0.000000       object
# 5          genres              0            0.000000       object
# 6            link              0            0.000000       object
# 7  published year             18            0.000179       object

# %%
data = data.dropna()

# %% [markdown]
# ### Check outlires in the data

# %%
def compute_outlires(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    columns_outlires = IQR[IQR >= 15]
    print(columns_outlires)

# %%
def remove_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    outliers = data[(data[column] < (Q1 - 1.5 * IQR)) | (data[column] > (Q3 + 1.5 * IQR))]
    data = data[~data.isin(outliers)]
    data = data[data['userId'].notnull()]
    return data

# %%
compute_outlires(data)
# Out:
# userId      300.0
# movieId    6843.0
# dtype: float64

# %%
data = remove_outliers(data, "movieId")
data = remove_outliers(data, "userId")

# %%
data
# Out:
#         userId  movieId  rating      date  \
# 0          1.0      1.0     4.0  30-07-00
# 1          5.0      1.0     4.0  08-11-96
# 2          7.0      1.0     4.5  25-01-05
# 3         15.0      1.0     2.5  13-11-17
# 4         17.0      1.0     4.5  18-05-11
# ...        ...      ...     ...       ...
# 100674   610.0   6095.0     3.5  19-11-16
# 100675   610.0   7202.0     3.0  04-05-17
# 100676   610.0   7562.0     2.5  19-11-16
# 100677   610.0   7984.0     4.0  28-05-17
# 100678   610.0   8840.0     1.0  19-11-16
#
#                                                     title  \
# 0                                        Toy Story (1995)
# 1                                        Toy Story (1995)
# 2                                        Toy Story (1995)
# 3                                        Toy Story (1995)
# 4                                        Toy Story (1995)
# ...                                                   ...
# 100674  Dragon Lord (a.k.a. Dragon Strike) (Long Xiao ...
# 100675                          Beyond Re-Animator (2003)
# 100676                                   Dobermann (1997)
# 100677                                 From Beyond (1986)
# 100678             Who's That Knocking at My Door? (1967)
#
#                                              genres  \
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1       Adventure|Animation|Children|Comedy|Fantasy
# 2       Adventure|Animation|Children|Comedy|Fantasy
# 3       Adventure|Animation|Children|Comedy|Fantasy
# 4       Adventure|Animation|Children|Comedy|Fantasy
# ...                                             ...
# 100674                                       Action
# 100675                                       Horror
# 100676                                 Action|Crime
# 100677                                Horror|Sci-Fi
# 100678                                        Drama
#
#                                link published year
# 0       www.imdb.com/title/tt114709         (1995)
# 1       www.imdb.com/title/tt114709         (1995)
# 2       www.imdb.com/title/tt114709         (1995)
# 3       www.imdb.com/title/tt114709         (1995)
# 4       www.imdb.com/title/tt114709         (1995)
# ...                             ...            ...
# 100674   www.imdb.com/title/tt84266         (1982)
# 100675  www.imdb.com/title/tt222812         (2003)
# 100676  www.imdb.com/title/tt118996         (1997)
# 100677   www.imdb.com/title/tt91083         (1986)
# 100678   www.imdb.com/title/tt63803         (1967)
#
# [77939 rows x 8 columns]

# %%
data.to_csv(r'movie_recommendation.csv', index = False)
